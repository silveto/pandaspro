# %% [markdown]
# ### 1. Load libraties

# %%
import pandas as pd
import numpy as np
import re # Regular expression library

# StringIO - to read dataframe from string
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %% [markdown]
# ### 2. Split file data into separate logs

# %%
file_name = "../data/DF/DF_NASKNX07A.txt"
with open(file_name, 'r') as open_file:
    txt = open_file.read()
    separate_logs = txt.split('\n\n')

# %% [markdown]
# ### 3. Get separate dataframes: log info and data

# %%
log_dfs = []
for log in separate_logs:
    if not "ERROR" in log and log != '':
        log = log.strip()
        log_info = re.match( r'# (.* \d{4}).*\((.*)\) INFO\n# hostname: (.*) serialno: (\d+)\n', log, re.M).groups()
        print(log_info)
        log_data = pd.read_table(StringIO(log), skiprows=3, header=None, sep=r"\s+",
                     names=['Filesystem','kbytes','used','avail','capacity','Mounted on'])
        log_data['date'] = log_info[0]
        log_data['date'] = pd.to_datetime(log_data['date'], format='%a %b %d %H:%M:%S %Y')
        log_data['ASUP_Type'] = log_info[1]
        log_data['hostname'] = log_info[2]
        log_data['serial_no'] = log_info[3]
        log_data = log_data[['date', 'ASUP_Type','hostname','serial_no','Filesystem','kbytes','used','avail','capacity','Mounted on']]
        log_dfs.append(log_data)
# Out:
# ('Sun Jul  2 00:34:30 2017', 'WEEKLY_LOG', 'NASKNX07A', '451416000026')
# ('Sun Jun 25 00:33:39 2017', 'WEEKLY_LOG', 'NASKNX07A', '451416000026')
# ('Sun Jun 18 00:22:49 2017', 'WEEKLY_LOG', 'NASKNX07A', '451416000026')
# ('Sun Jun 11 00:22:06 2017', 'WEEKLY_LOG', 'NASKNX07A', '451416000026')

# %% [markdown]
# ### 4. Concatenate all dataframes and see result

# %%
df = pd.concat(log_dfs, axis=0).reset_index(drop=True)

# %%
df.shape
# Out:
# (630, 10)

# %%
df
# Out:
#                    date   ASUP_Type   hostname     serial_no  \
# 0   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 1   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 2   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 3   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 4   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 5   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 6   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 7   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 8   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 9   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 10  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 11  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 12  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 13  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 14  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 15  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 16  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 17  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 18  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 19  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 20  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 21  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 22  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 23  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 24  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 25  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 26  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 27  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 28  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# 29  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026
# ..                  ...         ...        ...           ...
# 600 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 601 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 602 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 603 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 604 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 605 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 606 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 607 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 608 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 609 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 610 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 611 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 612 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 613 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 614 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 615 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 616 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 617 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 618 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 619 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 620 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 621 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 622 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 623 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 624 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 625 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 626 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 627 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 628 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
# 629 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026
#
#                                   Filesystem      kbytes       used  \
# 0                                 /vol/vol0/   274596860    9436936
# 1                        /vol/vol0/.snapshot    14452464    2674616
# 2              /vol/vf_NAS_AURDIVIC_rootvol/     1992296      13404
# 3     /vol/vf_NAS_AURDIVIC_rootvol/.snapshot      104856       7000
# 4               /vol/wd_aurdivic_hobo_vol01/  2040109468    2405664
# 5      /vol/wd_aurdivic_hobo_vol01/.snapshot   107374180      20308
# 6             /vol/wd_aurdivic_branch_vol01/  2040109468     110912
# 7    /vol/wd_aurdivic_branch_vol01/.snapshot   107374180      20972
# 8               /vol/vf_NAS_AURDI02_rootvol/     1992296      15640
# 9      /vol/vf_NAS_AURDI02_rootvol/.snapshot      104856       6140
# 10                    /vol/A3DOCKD0052_USER/     3735552      13520
# 11           /vol/A3DOCKD0052_USER/.snapshot      196608       1592
# 12                 /vol/A3DOCKD0052_PROFILE/     3735552      36696
# 13        /vol/A3DOCKD0052_PROFILE/.snapshot      196608       1544
# 14                  /vol/A3DOCKD0052_SHARED/   547880960   89636792
# 15         /vol/A3DOCKD0052_SHARED/.snapshot    28835840      18468
# 16               /vol/vf_NAS_AURINT_rootvol/     1992296       1920
# 17      /vol/vf_NAS_AURINT_rootvol/.snapshot      104856      10488
# 18              /vol/vf_NAS_AURIACT_rootvol/     1992296       1928
# 19     /vol/vf_NAS_AURIACT_rootvol/.snapshot      104856      10988
# 20              /vol/vf_NAS_AURITAS_rootvol/     1992296       1916
# 21     /vol/vf_NAS_AURITAS_rootvol/.snapshot      104856      10976
# 22             /vol/wd_auriact_branch_vol01/   846725120  547755116
# 23    /vol/wd_auriact_branch_vol01/.snapshot    44564480  100826372
# 24             /vol/wd_auritas_branch_vol01/   527958016  362553788
# 25    /vol/wd_auritas_branch_vol01/.snapshot    27787264  112158092
# 26              /vol/wd_aurint_branch_vol01/   498073600   88009760
# 27     /vol/wd_aurint_branch_vol01/.snapshot    26214400   36561188
# 28              /vol/vf_NAS_AURIQLD_rootvol/     1992296       2028
# 29     /vol/vf_NAS_AURIQLD_rootvol/.snapshot      104856      13140
# ..                                       ...         ...        ...
# 600            /vol/wd_aurinsw_branch_vol14/  4980736000  501218332
# 601   /vol/wd_aurinsw_branch_vol14/.snapshot   262144000  116993612
# 602             /vol/vf_NAS_AURINSW_rootvol/      996148       1492
# 603    /vol/vf_NAS_AURINSW_rootvol/.snapshot       52428      11868
# 604                        /vol/sv_test_vol/     9961472       4664
# 605               /vol/sv_test_vol/.snapshot      524288       4300
# 606             /vol/wd_auriwa_branch_vol06/   398458880     549696
# 607    /vol/wd_auriwa_branch_vol06/.snapshot    20971520     191052
# 608                     /vol/vol_SIF_Dev_01/   263979008      40488
# 609            /vol/vol_SIF_Dev_01/.snapshot    13893632      47324
# 610                   /vol/prd_itf_mp_vol01/     5033168       3400
# 611          /vol/prd_itf_mp_vol01/.snapshot     1258288       1156
# 612                          /vol/vol_trace/     9961472    1730424
# 613                 /vol/vol_trace/.snapshot      524288       4760
# 614                     /vol/vol_trace_test/    19922944    6507516
# 615            /vol/vol_trace_test/.snapshot     1048576       6996
# 616                 /vol/vol_trace_test_qld/    19922944    4221776
# 617        /vol/vol_trace_test_qld/.snapshot     1048576       1856
# 618               /vol/Siebel_App_Datavol01/    10485760       7448
# 619      /vol/Siebel_App_Datavol01/.snapshot           0          0
# 620               /vol/Siebel_App_Datavol02/    10485760       9128
# 621      /vol/Siebel_App_Datavol02/.snapshot           0          0
# 622               /vol/Siebel_App_Datavol03/    10485760     178124
# 623      /vol/Siebel_App_Datavol03/.snapshot           0          0
# 624               /vol/Siebel_App_Datavol04/    10485760     179116
# 625      /vol/Siebel_App_Datavol04/.snapshot           0          0
# 626                    /vol/vf_test_rootvol/     9961472       4616
# 627           /vol/vf_test_rootvol/.snapshot      524288       4300
# 628                            /vol/TestVol/     9961472     169768
# 629                   /vol/TestVol/.snapshot      524288       4280
#
#           avail capacity                               Mounted on
# 0     265159924       3%                               /vol/vol0/
# 1      11777848      19%                      /vol/vol0/.snapshot
# 2       1978892       1%            /vol/vf_NAS_AURDIVIC_rootvol/
# 3         97856       7%   /vol/vf_NAS_AURDIVIC_rootvol/.snapshot
# 4    2037703804       0%             /vol/wd_aurdivic_hobo_vol01/
# 5     107353872       0%    /vol/wd_aurdivic_hobo_vol01/.snapshot
# 6    2039998556       0%           /vol/wd_aurdivic_branch_vol01/
# 7     107353208       0%  /vol/wd_aurdivic_branch_vol01/.snapshot
# 8       1976656       1%             /vol/vf_NAS_AURDI02_rootvol/
# 9         98716       6%    /vol/vf_NAS_AURDI02_rootvol/.snapshot
# 10      3722032       0%                   /vol/A3DOCKD0052_USER/
# 11       195016       1%          /vol/A3DOCKD0052_USER/.snapshot
# 12      3698856       1%                /vol/A3DOCKD0052_PROFILE/
# 13       195064       1%       /vol/A3DOCKD0052_PROFILE/.snapshot
# 14    458244168      16%                 /vol/A3DOCKD0052_SHARED/
# 15     28817372       0%        /vol/A3DOCKD0052_SHARED/.snapshot
# 16      1990376       0%              /vol/vf_NAS_AURINT_rootvol/
# 17        94368      10%     /vol/vf_NAS_AURINT_rootvol/.snapshot
# 18      1990368       0%             /vol/vf_NAS_AURIACT_rootvol/
# 19        93868      10%    /vol/vf_NAS_AURIACT_rootvol/.snapshot
# 20      1990380       0%             /vol/vf_NAS_AURITAS_rootvol/
# 21        93880      10%    /vol/vf_NAS_AURITAS_rootvol/.snapshot
# 22    298970004      65%            /vol/wd_auriact_branch_vol01/
# 23            0     226%   /vol/wd_auriact_branch_vol01/.snapshot
# 24    165404228      69%            /vol/wd_auritas_branch_vol01/
# 25            0     404%   /vol/wd_auritas_branch_vol01/.snapshot
# 26    410063840      18%             /vol/wd_aurint_branch_vol01/
# 27            0     139%    /vol/wd_aurint_branch_vol01/.snapshot
# 28      1990268       0%             /vol/vf_NAS_AURIQLD_rootvol/
# 29        91716      13%    /vol/vf_NAS_AURIQLD_rootvol/.snapshot
# ..          ...      ...                                      ...
# 600  4479517668      10%            /vol/wd_aurinsw_branch_vol14/
# 601   145150388      45%   /vol/wd_aurinsw_branch_vol14/.snapshot
# 602      994656       0%             /vol/vf_NAS_AURINSW_rootvol/
# 603       40560      23%    /vol/vf_NAS_AURINSW_rootvol/.snapshot
# 604     9956808       0%                        /vol/sv_test_vol/
# 605      519988       1%               /vol/sv_test_vol/.snapshot
# 606   397909184       0%             /vol/wd_auriwa_branch_vol06/
# 607    20780468       1%    /vol/wd_auriwa_branch_vol06/.snapshot
# 608   263938520       0%                     /vol/vol_SIF_Dev_01/
# 609    13846308       0%            /vol/vol_SIF_Dev_01/.snapshot
# 610     5029768       0%                   /vol/prd_itf_mp_vol01/
# 611     1257132       0%          /vol/prd_itf_mp_vol01/.snapshot
# 612     8231048      17%                          /vol/vol_trace/
# 613      519528       1%                 /vol/vol_trace/.snapshot
# 614    13415428      33%                     /vol/vol_trace_test/
# 615     1041580       1%            /vol/vol_trace_test/.snapshot
# 616    15701168      21%                 /vol/vol_trace_test_qld/
# 617     1046720       0%        /vol/vol_trace_test_qld/.snapshot
# 618    10478312       0%               /vol/Siebel_App_Datavol01/
# 619           0     ---%      /vol/Siebel_App_Datavol01/.snapshot
# 620    10476632       0%               /vol/Siebel_App_Datavol02/
# 621           0     ---%      /vol/Siebel_App_Datavol02/.snapshot
# 622    10307636       2%               /vol/Siebel_App_Datavol03/
# 623           0     ---%      /vol/Siebel_App_Datavol03/.snapshot
# 624    10306644       2%               /vol/Siebel_App_Datavol04/
# 625           0     ---%      /vol/Siebel_App_Datavol04/.snapshot
# 626     9956856       0%                    /vol/vf_test_rootvol/
# 627      519988       1%           /vol/vf_test_rootvol/.snapshot
# 628     9791704       2%                            /vol/TestVol/
# 629      520008       1%                   /vol/TestVol/.snapshot
#
# [630 rows x 10 columns]
